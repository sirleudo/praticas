# %% [markdown]
# <a href="https://colab.research.google.com/github/sirleudo/praticas/blob/master/Decision_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Decision Tree

# %%
# importar os pacotes necessários
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# import o arquivo
df = pd.read_csv("http://dl.dropboxusercontent.com/s/6d91j46mkcdj4qv/heart-disease-clean.csv?dl=1")

# ver as primeiras entradas
print(f'Tamanho de df: {(df.shape)}\n')
df.head(10)
# Out:
# Tamanho de df: (303, 14)
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 5  56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 6  62.0  0.0  4.0     140.0  268.0  0.0      2.0    160.0    0.0      3.6
# 7  57.0  0.0  4.0     120.0  354.0  0.0      0.0    163.0    1.0      0.6
# 8  63.0  1.0  4.0     130.0  254.0  0.0      2.0    147.0    0.0      1.4
# 9  53.0  1.0  4.0     140.0  203.0  1.0      2.0    155.0    1.0      3.1
#
#    slope   ca  thal  num
# 0    3.0  0.0   6.0    0
# 1    2.0  3.0   3.0    1
# 2    2.0  2.0   7.0    1
# ...

# %%
# 1. escolher e importar um modelo
from sklearn.tree import DecisionTreeClassifier

# 2. instanciar e escolher os hyperparameters
model = DecisionTreeClassifier(max_depth=4, criterion="entropy")

# 3. separar os dados entre feature matrix e target vector
X = df.drop('num', axis=1)
y = df['num']

# 3.1 dividir o dataset entre treino e tete
X_train, X_test, y_train, y_test = train_test_split(X, y)

# 4. fit do modelo (treinar)
model.fit(X_train, y_train)

# 5. fazer previsões em cima de novos dados
y_pred = model.predict(X_test)

# %%
# classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80        44
#            1       0.73      0.75      0.74        32
#
#     accuracy                           0.78        76
#    macro avg       0.77      0.77      0.77        76
# weighted avg       0.78      0.78      0.78        76

# %%
# matrix de confusão
fig, ax = plt.subplots()
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, ax=ax)

ax.set_title("Matriz de Confusão")
ax.set_ylabel('Verdadeiro')
ax.set_xlabel('Previsto')

plt.show()

# %%
# ver performance do algoritmo
print("\nAccuracy Score:")
print(accuracy_score(y_pred, y_pred))
# Out:
# Accuracy Score:
# 1.0

# %%
# importar biblioteca
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus

# criar DOT
dot = export_graphviz(model, filled=True, rounded=True,
                      feature_names=X.columns, class_names=['0', '1'])

# plotar
graph = pydotplus.graph_from_dot_data(dot)
Image(graph.create_png())
